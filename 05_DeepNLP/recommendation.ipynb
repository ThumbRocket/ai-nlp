# %% [markdown]
# # Movie Recommendation System with Text Embedding

# %% [markdown]
# ![Alt text](https://repository-images.githubusercontent.com/275336521/20d38e00-6634-11eb-9d1f-6a5232d0f84f)

# %% [markdown]
# ## Import requirements

# %%
! pip install faiss-gpu
# Out:
# Requirement already satisfied: faiss-gpu in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (1.7.2)

# %%
! pip install sentence_transformers ## For textual similarity, using pretrained models
# Out:
# Requirement already satisfied: sentence_transformers in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (4.44.0)
# Requirement already satisfied: tqdm in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (2.4.0)
# Requirement already satisfied: numpy in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (1.5.1)
# Requirement already satisfied: scipy in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (0.24.5)
# Requirement already satisfied: Pillow in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.2)
# Requirement already satisfied: networkx in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from tqdm.notebook import tqdm
import faiss
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ## Load Dataset and Model

# %%
imdb_movies=pd.read_csv("https://raw.githubusercontent.com/tommyEzreal/0701_samsung/main/imdb_movies_0626.csv")
imdb_movies

# we will encode 'Description' columnn for our recommendation system
# Out:
#      Unnamed: 0                                     Movie Name  \
# 0             0                       The Shawshank Redemption
# 1             1                                  The Godfather
# 2             2                                The Dark Knight
# 3             3  The Lord of the Rings: The Return of the King
# 4             4                               Schindler's List
# ..          ...                                            ...
# 995         995                                        Sabrina
# 996         996                          From Here to Eternity
# 997         997                Snow White and the Seven Dwarfs
# 998         998                                   The 39 Steps
# 999         999                              The Invisible Man
#
#     Year of Release Watch Time  Movie Rating Meatscore of movie   Votes  \
# 0            (1994)    142 min           9.3         81          34,709
# 1            (1972)    175 min           9.2        100          34,709
# 2            (2008)    152 min           9.0         84          34,709
# 3            (2003)    201 min           9.0         94          34,709
# 4            (1993)    195 min           9.0         94          34,709
# ..              ...        ...           ...                ...     ...
# 995          (1954)    113 min           7.6         72          34,709
# 996          (1953)    118 min           7.6         85          34,709
# 997          (1937)     83 min           7.6         95          34,709
# 998          (1935)     86 min           7.6         93          34,709
# 999          (1933)     71 min           7.6         87          34,709
#
#         Gross                                        Description   id  cluster
# 0     $28.34M  Two imprisoned men bond over a number of years...    0        2
# 1    $134.97M  The aging patriarch of an organized crime dyna...    1        2
# 2    $534.86M  When the menace known as the Joker wreaks havo...    2        2
# 3    $377.85M  Gandalf and Aragorn lead the World of Men agai...    3        0
# 4     $96.90M  In German-occupied Poland during World War II,...    4        7
# ..        ...                                                ...  ...      ...
# 995    %^%^%^  A playboy becomes interested in the daughter o...  995        1
# 996   $30.50M  At a U.S. Army base in 1941 Hawaii, a private ...  996        7
# 997  $184.93M  Exiled into the dangerous forest by her wicked...  997        8
# 998    %^%^%^  A man in London tries to help a counter-espion...  998        5
# 999    %^%^%^  A scientist finds a way of becoming invisible,...  999        6
#
# [1000 rows x 11 columns]

# %%
k = 0
print("Movie Title:",imdb_movies['Movie Name'][k])
print("Movie description:", imdb_movies['Description'][k])
# Out:
# Movie Title: The Shawshank Redemption
# Movie description: Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.

# %%
# load bi-encoder model
model = SentenceTransformer('paraphrase-distilroberta-base-v1') # Loads the distil roberta model,whcih was trained on millions of data
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.78k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /home/devrok/.conda/envs/nlp_pt/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Query-based Recommendation

# %% [markdown]
# ![Example Image](https://drive.google.com/uc?id=1biO4IGKqeiyChgOBVjqxdnvitBWImGkn)

# %% [markdown]
# - `User Query Input`: The user inputs a description or keywords for the movie they want to watch.
# - `Query Embedding`: Convert the user's query into an embedding vector. This involves mapping the text into a high-dimensional vector space using a natural language processing model.
# - `Movie Description Embeddings`: Similarly, convert each movie description in the dataframe into embedding vectors.
# - `Calculating Similarity`:
# Compute the cosine similarity between the embedding vector of the user's query and the embedding vectors of all movie descriptions. Cosine similarity measures how similar two vectors are by calculating the cosine of the angle between them.
# Recommend the Most Similar Movie: Recommend the movie with the highest similarity score.
# - `Recommend the Most Similar Movie` :
# Identify the movie with the highest similarity score and recommend it to the user as the best match for their query.

# %%
# what is faiss? : reduce the computational cost of calculating embedding similarity
# prior to calculating simialrity, first cluster the index pool -> assign query to most similar cluster , then calculate the similarity in the cluster

def make_faiss_index(df):
    descriptions=df['Description'].tolist()
    print("Number of Movie Description ",len(descriptions))

    # for each movie description, encode and get embeddings
    des_embeddings = []
    for des in tqdm(descriptions):
        des_embeddings.append(model.encode(des))

    # convert the list to a numpy array
    des_embeddings_array = np.array(des_embeddings)
    print("Shape of the EMbeddings is ",des_embeddings_array.shape)

    faiss.normalize_L2(des_embeddings_array) ## Normalising the Embeddings


    dim=768 # we get a 768 dimension vector following the dimension of Roberta
    ncentroids=50 # this is a hyperparameter, and indicates number of clusters to be split into
    m=16 #
    quantiser = faiss.IndexFlatL2(dim)
    index = faiss.IndexIVFPQ (quantiser, dim,ncentroids, m , 8)
    index.train(des_embeddings_array) # this step, will do the clustering and create the clusters
    faiss.write_index(index, "trained.index")

    # add the embeddings to the trained Index.
    ids=df['id'].tolist()
    ids=np.array(ids)
    index.add_with_ids(des_embeddings_array,ids)
    faiss.write_index(index,"block.index")

    return des_embeddings, index

des_embeddings, index = make_faiss_index(imdb_movies)
# Out:
# Number of Movie Description  1000
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Shape of the EMbeddings is  (1000, 768)
# WARNING clustering 1000 points to 50 centroids: please provide at least 1950 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 1000 points to 256 centroids: please provide at least 9984 training points

# %%
# calculate cosine similarity
def calculateInnerProduct(L2_score):
    return (2-math.pow(L2_score,2))/2


def searchFAISSIndex(data,id_col_name,query,index,nprobe,model,topk=10):
    #convert the query into embeddings
    query_embedding=model.encode([query])[0]
    dim=query_embedding.shape[0]
    query_embedding=query_embedding.reshape(1,dim)
    faiss.normalize_L2(query_embedding)

    index.nprobe=nprobe

    D,I=index.search(query_embedding,topk)
    ids=[i for i in I][0]
    L2_score=[d for d in D][0]
    inner_product=[calculateInnerProduct(l2) for l2 in L2_score]

    # visualization
    search_result=pd.DataFrame()
    search_result[id_col_name]=ids
    search_result['cosine_sim']=inner_product
    dat=data[data[id_col_name].isin(ids)]
    dat=pd.merge(dat,search_result,on=id_col_name)
    dat=dat.sort_values('cosine_sim',ascending=False)

    return dat, query_embedding

# %%
# use your own query !

query="Super Hero movie"
search_result, query_embedding =searchFAISSIndex(imdb_movies,"id",query,index,nprobe=10,model=model,topk=10)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#     id                                        Description  \
# 6  367  Earth's mightiest heroes must come together an...
# 8  605  In a time of conflict, a group of unlikely her...
# 4  280  In this luminous tale set in the area around S...
# 1   64  Teen Miles Morales becomes the Spider-Man of h...
# 2   65  After the devastating events of Avengers: Infi...
# 0    2  When the menace known as the Joker wreaks havo...
# 5  359  Determined to ensure Superman's ultimate sacri...
# 3   66  The Avengers and their allies must be willing ...
# 9  876  With the assistance of the Enterprise crew, Ad...
# 7  441  A crafty samurai helps a young man and his fel...
#
#                           Movie Name  cosine_sim
# 6                       The Avengers    0.464363
# 8       Rogue One: A Star Wars Story    0.433407
# 4                Time of the Gypsies    0.426380
# 1  Spider-Man: Into the Spider-Verse    0.425828
# 2                  Avengers: Endgame    0.417639
# 0                    The Dark Knight    0.412716
# 5       Zack Snyder's Justice League    0.402233
# 3             Avengers: Infinity War    0.400378
# 9    Star Trek II: The Wrath of Khan    0.392874
# 7                            Sanjuro    0.384667

# %%
query="Recommend me a romantic comedy"
search_result, query_embedding=searchFAISSIndex(imdb_movies,"id",query,index,nprobe=10,model=model,topk=10)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#     id                                        Description  \
# 2  339  While navigating their careers in Los Angeles,...
# 4  485  An egomaniacal film star develops a relationsh...
# 3  401  Two melancholy Hong Kong policemen fall in lov...
# 9  843  A simple Italian postman learns to love poetry...
# 7  720  In 1910s London, snobbish phonetics professor ...
# 8  756  A washed-up superhero actor attempts to revive...
# 1  220  Six short stories that explore the extremities...
# 5  495  A depressed wealthy businessman finds his life...
# 0  125  A New York City advertising executive goes on ...
# 6  516  Two men share an odd friendship while they car...
#
#                                         Movie Name  cosine_sim
# 2                                       La La Land    0.209603
# 4                                       The Artist    0.192226
# 3                                Chungking Express    0.184158
# 9                                      The Postman    0.176874
# 7                                     My Fair Lady    0.161797
# 8  Birdman or (The Unexpected Virtue of Ignorance)    0.159507
# 1                                       Wild Tales    0.156317
# 5                                       Jab We Met    0.145009
# 0                               North by Northwest    0.142427
# 6                                      Talk to Her    0.128067

# %%
query="Kids Animation"
search_result, query_embedding=searchFAISSIndex(imdb_movies,"id",query,index,nprobe=10,model=model,topk=10)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#     id                                        Description  \
# 0   60  While serving a five-year sentence for a viole...
# 5  373  In a small Tokyo apartment, twelve-year-old Ak...
# 1  104  The toys are mistakenly delivered to a day-car...
# 2  111  A cowboy doll is profoundly threatened and jea...
# 6  395  A baby boy, discovered in 1900 on an ocean lin...
# 7  751  Due to 12 y.o. Anna's asthma, she's sent to st...
# 4  176  A pragmatic paleontologist touring an almost c...
# 8  854  An examination of the machinations behind the ...
# 3  152  The youngest son of an alcoholic former boxer ...
# 9  989  Bagheera the Panther and Baloo the Bear have a...
#
#               Movie Name  cosine_sim
# 0              Capernaum    0.354904
# 5           Nobody Knows    0.291275
# 1            Toy Story 3    0.280464
# 2              Toy Story    0.268277
# 6     The Legend of 1900    0.262176
# 7  When Marnie Was There    0.252381
# 4          Jurassic Park    0.231739
# 8    Glengarry Glen Ross    0.225549
# 3                Warrior    0.219455
# 9        The Jungle Book    0.215666

# %% [markdown]
# ### embedding visualization

# %%
# Visualize embeddings using T-SNE
def visualize_embeddings_3queries(data1, embeddings1, query_embedding1, data2, embeddings2, query_embedding2, data3, embeddings3, query_embedding3, query1, query2, query3, perplexity=5):
    # Combine the embeddings
    combined_embeddings = np.vstack([embeddings1, query_embedding1, embeddings2, query_embedding2, embeddings3, query_embedding3])

    # Apply T-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity)
    tsne_results = tsne.fit_transform(combined_embeddings)

    # Generate colors
    palette = sns.color_palette("muted", 3)

    # Plot the results
    plt.figure(figsize=(14, 10))

    # Plot the first query results
    scatter1 = plt.scatter(
        tsne_results[:len(embeddings1), 0], tsne_results[:len(embeddings1), 1],
        color=palette[0], label=f'"{query1}" Results', alpha=0.7, marker='o'
    )

    # Plot the second query results
    scatter2 = plt.scatter(
        tsne_results[len(embeddings1) + 1:len(embeddings1) + 1 + len(embeddings2), 0], tsne_results[len(embeddings1) + 1:len(embeddings1) + 1 + len(embeddings2), 1],
        color=palette[1], label=f'"{query2}" Results', alpha=0.7, marker='^'
    )

    # Plot the third query results
    scatter3 = plt.scatter(
        tsne_results[len(embeddings1) + 1 + len(embeddings2) + 1:-1, 0], tsne_results[len(embeddings1) + 1 + len(embeddings2) + 1:-1, 1],
        color=palette[2], label=f'"{query3}" Results', alpha=0.7, marker='s'
    )

    # Highlight the query points
    plt.scatter(tsne_results[len(embeddings1), 0], tsne_results[len(embeddings1), 1], c=palette[0], marker='X', s=200, label=query1)
    plt.scatter(tsne_results[len(embeddings1) + 1 + len(embeddings2), 0], tsne_results[len(embeddings1) + 1 + len(embeddings2), 1], c=palette[1], marker='X', s=200, label=query2)
    plt.scatter(tsne_results[-1, 0], tsne_results[-1, 1], c=palette[2], marker='X', s=200, label=query3)

    # Annotate the points with movie names
    for i, txt in enumerate(data1['Movie Name']):
        plt.text(tsne_results[i, 0], tsne_results[i, 1], txt, fontsize=9, color=palette[0])

    for i, txt in enumerate(data2['Movie Name']):
        plt.text(tsne_results[len(embeddings1) + 1 + i, 0], tsne_results[len(embeddings1) + 1 + i, 1], txt, fontsize=9, color=palette[1])

    for i, txt in enumerate(data3['Movie Name']):
        plt.text(tsne_results[len(embeddings1) + 1 + len(embeddings2) + 1 + i, 0], tsne_results[len(embeddings1) + 1 + len(embeddings2) + 1 + i, 1], txt, fontsize=9, color=palette[2])

    plt.legend()
    plt.title('T-SNE visualization of movie embeddings for three queries')
    plt.show()

# Example usage
query1 = "Super Hero movie"
query2 = "Recommend me a romantic comedy"
query3 = "Kids Animation"

# Search results for query 1
search_result1, query_embedding1 = searchFAISSIndex(imdb_movies, "id", query1, index, nprobe=10, model=model, topk=10)
search_result1 = search_result1[['id', 'Description', 'Movie Name', 'cosine_sim']]
embeddings1 = np.array([model.encode([desc])[0] for desc in search_result1['Description'].tolist()])

# Search results for query 2
search_result2, query_embedding2 = searchFAISSIndex(imdb_movies, "id", query2, index, nprobe=10, model=model, topk=10)
search_result2 = search_result2[['id', 'Description', 'Movie Name', 'cosine_sim']]
embeddings2 = np.array([model.encode([desc])[0] for desc in search_result2['Description'].tolist()])

# Search results for query 3
search_result3, query_embedding3 = searchFAISSIndex(imdb_movies, "id", query3, index, nprobe=10, model=model, topk=10)
search_result3 = search_result3[['id', 'Description', 'Movie Name', 'cosine_sim']]
embeddings3 = np.array([model.encode([desc])[0] for desc in search_result3['Description'].tolist()])

# Visualize with adjusted perplexity
visualize_embeddings_3queries(search_result1, embeddings1, query_embedding1, search_result2, embeddings2, query_embedding2, search_result3, embeddings3, query_embedding3, query1, query2, query3, perplexity=5)
# Out:
# /tmp/ipykernel_572618/3645533544.py:35: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(tsne_results[len(embeddings1), 0], tsne_results[len(embeddings1), 1], c=palette[0], marker='X', s=200, label=query1)
# /tmp/ipykernel_572618/3645533544.py:36: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(tsne_results[len(embeddings1) + 1 + len(embeddings2), 0], tsne_results[len(embeddings1) + 1 + len(embeddings2), 1], c=palette[1], marker='X', s=200, label=query2)
# /tmp/ipykernel_572618/3645533544.py:37: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(tsne_results[-1, 0], tsne_results[-1, 1], c=palette[2], marker='X', s=200, label=query3)

# %% [markdown]
# ## User Histroy-based Recommendation

# %% [markdown]
# ![Example Image](https://drive.google.com/uc?id=16dw0Ud2-Wui62WJ4ZHRoYb6XRpR58ecr)

# %% [markdown]
# - `User Viewing History Input`:
# The system accesses the user's viewing history, which includes descriptions of all the movies the user has watched.
#
# - `Movie Description Embeddings`: Convert each movie description in the user's viewing history into embedding vectors using a pre-trained language model (e.g., BERT).
# - `User Embedding`: Calculate the average of all movie description embeddings from the user's viewing history to create a single embedding vector representing the user's overall movie preferences.
# - `Calculating Similarity`:
# Calculate the cosine similarity between the user's embedding vector and the embedding vectors of all movies in the database. Cosine similarity measures the cosine of the angle between two vectors, indicating how similar the vectors are. A similarity score closer to 1 means the vectors are more similar.
# - `Recommend Movies`:
# Identify the movies with the highest similarity scores and recommend them to the user as the best matches for their viewing history and preferences.

# %%
def make_user_history(df):

    user_ids = sorted(df['cluster'].unique())

    user_history = {}
    for user_id in user_ids:
        # synthetic user history
        description_list = df[df['cluster']==user_id]['Description'].tolist()[:50]
        movie_name_list = df[df['cluster']==user_id]['Movie Name'].tolist()[:50]
        ids = df[df['cluster']==user_id]['id'].tolist()[:50]
        user_history[f'user_{user_id}'] = {'Movie Name': movie_name_list, "Description": description_list, "id": ids}

        #prediction_pool
        indices_to_drop = df[df['id'].isin(ids)].index
        prediction_pool = df.drop(indices_to_drop)
        user_history[f'user_{user_id}']['pred_pool'] = prediction_pool

        #GT
        GT_description = df[df['cluster']==user_id]['Description'].tolist()[50:]
        GT_movie_name = df[df['cluster']==user_id]['Movie Name'].tolist()[50:]

        user_history[f'user_{user_id}']['GT'] = [(d, n) for d,n in zip(GT_description, GT_movie_name)]

    return user_history

user_history = make_user_history(imdb_movies)

# %%
user_history['user_6']['Movie Name']
# Out:
# ['Inception',
#  'The Matrix',
#  "One Flew Over the Cuckoo's Nest",
#  'Top Gun: Maverick',
#  "It's a Wonderful Life",
#  'Whiplash',
#  'The Intouchables',
#  'Back to the Future',
#  'Joker',
#  'Coco',
#  'Amadeus',
#  'Witness for the Prosecution',
#  'The Hunt',
#  'Spider-Man: No Way Home',
#  'Good Will Hunting',
#  'Once Upon a Time in America',
#  'A Clockwork Orange',
#  'The Apartment',
#  'Vertigo',
#  'Pather Panchali',
#  'Ikiru',
#  'Andhadhun',
#  'Green Book',
#  'The Secret in Their Eyes',
#  'The Wolf of Wall Street',
#  'A Beautiful Mind',
#  'The Truman Show',
#  'The Elephant Man',
#  'Taxi Driver',
#  'Sherlock Jr.',
#  'A Silent Voice: The Movie',
#  'OMG: Oh My God!',
#  'The Grand Budapest Hotel',
#  'Gone Girl',
#  'A Wednesday',
#  'Into the Wild',
#  'Munna Bhai M.B.B.S.',
#  'Trainspotting',
#  'Groundhog Day',
#  'Time of the Gypsies',
#  'Paris, Texas',
#  'Rocky',
#  'Network',
#  'Anand',
#  'Cool Hand Luke',
#  'Wild Strawberries',
#  'Throne of Blood',
#  'On the Waterfront',
#  'Ace in the Hole',
#  'Mr. Smith Goes to Washington']

# %%
prediction_pool_df = user_history['user_6']['pred_pool']

prediction_pool_df=prediction_pool_df.reset_index(drop=True)
prediction_pool_df['id']=prediction_pool_df.index

pool_embeddings, index = make_faiss_index(prediction_pool_df)
# Out:
# Number of Movie Description  950
#   0%|          | 0/950 [00:00<?, ?it/s]
# Shape of the EMbeddings is  (950, 768)
# WARNING clustering 950 points to 50 centroids: please provide at least 1950 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points
# WARNING clustering 950 points to 256 centroids: please provide at least 9984 training points

# %%
def make_user_embedding(user_history):
    ## Convert the list of user history into embeddings
    user_embeddings = [model.encode([hist])[0] for hist in tqdm(user_history)]
    print(user_embeddings[0].shape)

    ## Calculate the mean of the embeddings
    avg_user_embedding = np.mean(user_embeddings, axis=0) ## FILL ##
    print(avg_user_embedding.shape)

    return avg_user_embedding

# %%
user_history_sample = user_history['user_6']['Description']
sample_embedding = make_user_embedding(user_history_sample)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (768,)
# (768,)

# %%
def searchFAISSIndex_user_history(data, id_col_name, user_history, index, nprobe, model, topk=50):

    avg_user_embedding = make_user_embedding(user_history)

    # Reshape the average query embedding
    dim = avg_user_embedding.shape[0]
    avg_user_embedding = avg_user_embedding.reshape(1, dim)

    # Normalize the query embedding
    faiss.normalize_L2(avg_user_embedding)

    # Set the nprobe parameter
    index.nprobe = nprobe

    # Perform the search
    D, I = index.search(avg_user_embedding, topk)

    # Extract IDs and L2 scores
    ids = [i for i in I][0]
    L2_score = [d for d in D][0]

    # Calculate cosine similarities
    inner_product = [calculateInnerProduct(l2) for l2 in L2_score]

    # Visualization
    search_result = pd.DataFrame()
    search_result[id_col_name] = ids
    search_result['cosine_sim'] = inner_product
    dat = data[data[id_col_name].isin(ids)]
    dat = pd.merge(dat, search_result, on=id_col_name)
    dat = dat.sort_values('cosine_sim', ascending=False)

    return dat, avg_user_embedding

# %%
user_history_input = user_history['user_6']['Description']
recommend_pool = user_history['user_6']['pred_pool']

search_result, avg_user_embedding=searchFAISSIndex_user_history(recommend_pool,"id",user_history_input,index,nprobe=10,model=model,topk=20)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (768,)
# (768,)
#      id                                        Description  \
# 5   590  A film crew goes to a tropical island for an e...
# 12  786  Two eighth-graders start to have feelings for ...
# 19  944  Two Boston area detectives investigate a littl...
# 16  879  A man afraid to fly must ensure that a plane l...
# 2   353  In a near future, a lonely writer develops an ...
# 11  782  Through the innocent eyes of Bruno, the eight-...
# 3   444  A series of stories following a week in the li...
# 17  888  A pair of NYPD detectives in the Narcotics Bur...
# 13  813  When her grandson is kidnapped during the Tour...
# 18  925  Shot documentary-style, this film follows the ...
# 8   676  A genetically inferior man assumes the identit...
# 6   623  A pair of young lovers flee their New England ...
# 10  751  Due to 12 y.o. Anna's asthma, she's sent to st...
# 15  878  The accidental death of the older son of an af...
# 4   535  Jack Skellington, king of Halloween Town, disc...
# 0    79  On a journey to find the cure for a Tatarigami...
# 1   272  A group of Serbian socialists prepares for the...
# 9   689  The victims of an encephalitis epidemic many y...
# 14  876  With the assistance of the Enterprise crew, Ad...
# 7   666  Sixteen-year-old Lilja and her only friend, th...
#
#                          Movie Name  cosine_sim
# 5                         King Kong    0.819852
# 12                          Flipped    0.813159
# 19                   Gone Baby Gone    0.810841
# 16                        Airplane!    0.805102
# 2                               Her    0.791331
# 11   The Boy in the Striped Pajamas    0.786795
# 3                     La dolce vita    0.786691
# 17            The French Connection    0.776974
# 13       The Triplets of Belleville    0.776490
# 18                     End of Watch    0.774464
# 8                           Gattaca    0.772742
# 6                  Moonrise Kingdom    0.772457
# 10            When Marnie Was There    0.772270
# 15                  Ordinary People    0.770180
# 4    The Nightmare Before Christmas    0.757624
# 0                 Princess Mononoke    0.757143
# 1                       Underground    0.756813
# 9                        Awakenings    0.756236
# 14  Star Trek II: The Wrath of Khan    0.756162
# 7                      Lilya 4-Ever    0.752901

# %%
gts = user_history['user_6']['GT']
gt_movie_names = [tpl[1] for tpl in gts]
pred_movie_names = search_result['Movie Name'].to_list()

count = 0
for pred in pred_movie_names:
    if pred in gt_movie_names:
        count += 1
        print(pred)
# Out:
# Airplane!
# The Nightmare Before Christmas

# %% [markdown]
# ### Manual User history

# %%
# manually input your movie preferences !

user_history_input = [
    "animation",
    "fantasy",
    "pixar",
    "ghibli"
    ]

# %%
search_result, _=searchFAISSIndex_user_history(recommend_pool,"id",user_history_input,index,nprobe=10,model=model,topk=20)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# (768,)
# (768,)
#      id                                        Description  \
# 6   250  A rat who can cook makes an unusual alliance w...
# 17  946  A profile of Ian Curtis, the enigmatic singer ...
# 18  949  In 1985 where former superheroes exist, the mu...
# 12  804  A faded movie star and a neglected young woman...
# 2    77  A man with short-term memory loss attempts to ...
# 5   176  A pragmatic paleontologist touring an almost c...
# 0    10  While Frodo and Sam edge closer to Mordor with...
# 4   118  Two grifters team up to pull off the ultimate ...
# 8   310  A young boy, left without attention, delves in...
# 13  815  The story of 160 elite U.S. soldiers who dropp...
# 3   105  In Nazi-occupied France during World War II, a...
# 7   282  When two girls move to the country to be near ...
# 1    74  In the distant future, a small waste-collectin...
# 9   367  Earth's mightiest heroes must come together an...
# 16  936  A five-year-old boy develops a relationship wi...
# 11  667  A TV interviewer and his cameraman meet a form...
# 15  925  Shot documentary-style, this film follows the ...
# 10  502  An impromptu goodbye party for Professor John ...
# 14  890  A recently blinded woman is terrorized by a tr...
#
#                                Movie Name  cosine_sim
# 6                             Ratatouille    0.331638
# 17                                Control    0.302282
# 18                               Watchmen    0.293644
# 12                    Lost in Translation    0.266942
# 2                                 Memento    0.253603
# 5                           Jurassic Park    0.232798
# 0   The Lord of the Rings: The Two Towers    0.224481
# 4                               The Sting    0.220740
# 8                           The 400 Blows    0.216375
# 13                        Black Hawk Down    0.213513
# 3                    Inglourious Basterds    0.209997
# 7                      My Neighbor Totoro    0.196531
# 1                                  WALL·E    0.195524
# 9                            The Avengers    0.195454
# 16                                  Ponyo    0.189256
# 11                     Millennium Actress    0.184251
# 15                           End of Watch    0.180363
# 10                     The Man from Earth    0.173276
# 14                        Wait Until Dark    0.172057

# %%
user_history_input = [
    "science",
    "alien",
    "spaceship",
    "portal"
    ]

# %%
search_result, _=searchFAISSIndex_user_history(recommend_pool,"id",user_history_input,index,nprobe=10,model=model,topk=20)
search_result=search_result[['id','Description','Movie Name','cosine_sim']]
search_result
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# (768,)
# (768,)
#      id                                        Description  \
# 16  949  In 1985 where former superheroes exist, the mu...
# 7   376  When two brothers are forced to fight in the K...
# 4   250  A rat who can cook makes an unusual alliance w...
# 9   393  A pop singer gives up her career to become an ...
# 5   276  A man's coerced confession to an I.R.A. bombin...
# 6   361  A noble family becomes embroiled in a war for ...
# 8   385  While trying to lead a quiet suburban life, a ...
# 1   118  Two grifters team up to pull off the ultimate ...
# 14  573  Disturbed Blanche DuBois moves in with her sis...
# 2   176  A pragmatic paleontologist touring an almost c...
# 10  403  A prep school student needing money agrees to ...
# 3   197  An elderly man and his dog struggle to survive...
# 12  493  Violence ensues after an extraterrestrial race...
# 13  572  Tough cop Dave Bannion takes on a politically ...
# 0   108  Unscrupulous boxing promoters, violent bookmak...
# 15  890  A recently blinded woman is terrorized by a tr...
# 11  474  A young German boy in the Hitler Youth whose h...
#
#                             Movie Name  cosine_sim
# 16                            Watchmen    0.326260
# 7   Tae Guk Gi: The Brotherhood of War    0.301175
# 4                          Ratatouille    0.294353
# 9                         Perfect Blue    0.281662
# 5            In the Name of the Father    0.275292
# 6                                 Dune    0.265930
# 8                      The Incredibles    0.260186
# 1                            The Sting    0.258735
# 14            A Streetcar Named Desire    0.249112
# 2                        Jurassic Park    0.241513
# 10                    Scent of a Woman    0.238082
# 3                           Umberto D.    0.229702
# 12                          District 9    0.222364
# 13                        The Big Heat    0.219875
# 0                               Snatch    0.216836
# 15                     Wait Until Dark    0.216738
# 11                         Jojo Rabbit    0.215329
